# %%
import pandas as pd
import os.path as op

# %%
df = pd.read_table('/Users/mrenke/data/ds-stressrisk/sub-01/ses-1/func/sub-01_ses-1_task-risk_run-1_events.tsv')

# %%
onsets_s1 =[]
n1 = []
durations_n1 = []
onsets_s2 =[]
n2 =[]

for row in df.iterrows():
    if row[1]['trial_type'] == 'stimulus 1':
        onsets_s1.append(row[1]['onset'])
        n1.append(row[1]['n1'])
        durations_n1.append(0.6)

    elif row[1]['trial_type'] == 'stimulus 2':
        onsets_s2.append(row[1]['onset']) 
        n2.append(row[1]['n2'])  

             
durations_n2 = durations_n1

# %%
stim1 =pd.DataFrame(data= {'onset':onsets_s1, 'duration':durations_n1,'strength':n1})
fn = '/Users/mrenke/data/ds-stressrisk/sub-01/ses-1/func/sub-01_ses-1_task-risk_run-1_events_n1-forfsl.txt'
stim1.to_csv(fn, sep ='\t',index=False,header=False)

# %%
stim2 =pd.DataFrame(data= {'onset':onsets_s2, 'duration':durations_n2,'strength':n2})
fn = '/Users/mrenke/data/ds-stressrisk/sub-01/ses-1/func/sub-01_ses-1_task-risk_run-1_events_n2-forfsl.txt'
stim2.to_csv(fn, sep ='\t',index=False,header=False)

# %%
onsets_s1_r =[]
onsets_s1_s =[]
n1_r = []
durations_n1 = []
onsets_s1_r =[]
onsets_s1_s =[]
n2 =[]

for row in df.iterrows():
    if row[1]['trial_type'] == 'stimulus 1':
        onsets_s1.append(row[1]['onset'])
        n1.append(row[1]['n1'])
        durations_n1.append(0.6)

    elif row[1]['trial_type'] == 'stimulus 2':
        onsets_s2.append(row[1]['onset']) 
        n2.append(row[1]['n2'])  

             
durations_n2 = durations_n1

# %%
# confound file
df = pd.read_table('/Users/mrenke/data/ds-stressrisk/derivatives/fmriprep/sub-01/ses-1/func/sub-01_ses-1_task-risk_run-1_desc-confounds_timeseries.tsv')

# %%
fmriprep_confounds_include = ['global_signal', 'dvars', 'framewise_displacement', 'trans_x',
                                  'trans_y', 'trans_z', 'rot_x', 'rot_y', 'rot_z',
                                  'a_comp_cor_00', 'a_comp_cor_01', 'a_comp_cor_02', 'a_comp_cor_03', 'cosine00', 'cosine01', 'cosine02'
                                  ]

# %%
fn = '/Users/mrenke/data/ds-stressrisk/derivatives/fmriprep/sub-01/ses-1/func/sub-01_ses-1_task-risk_run-1_desc-confounds_timeseries_forfsl.txt'

df[fmriprep_confounds_include].to_csv(fn, sep ='\t',index=False,header=False)
