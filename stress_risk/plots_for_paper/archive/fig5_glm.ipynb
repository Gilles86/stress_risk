# %%
import nibabel as nib
import numpy as np
import nilearn.plotting as nipl 
import nilearn.image as niim
import matplotlib as mpl
import os.path  as op

bids_folder = '/Volumes/mrenkeED/data/ds-stressrisk'

# %%
nifti_fn = 'mPFC_mask_thresh.nii'#'mPFC_cluster.nii'
spm_file = op.join(bids_folder,'derivatives','spm','NLC-1_con_2ndlevels','2ndlevel_NLC-1_v2',nifti_fn)
spm = nib.load(spm_file)
cut_coords = tuple([-4,6,8,10])
#colormap = mpl.colors.Colormap(name='cool')
nipl.plot_stat_map(spm, draw_cross=False, title=f'', display_mode='x', cut_coords =cut_coords ,colorbar=False,cmap='cool')# threshold = 2.5,
