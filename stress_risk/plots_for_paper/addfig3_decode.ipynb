# %%
import pandas as pd
import os.path as op
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

bids_folder = '/Users/mrenke/data/ds-stressrisk'
plot_folder_path = '/Users/mrenke/Desktop/StressRisk/figures/plots/fig_3'

# %%
# visualize decoding procedure

# 1. neural data: beta x location x trial

betas = np.random.randint(1,10, 5)

df = pd.DataFrame(data=[range(0,5),betas ])
fig = sns.barplot(data=df) # plt.bar(x= range(0,5),height=betas,color = c) # c = sns.color_palette(n_colors=5)
fig.set_facecolor([0.0, 0.0, 0.0, 0.0])
sns.despine()
plt.savefig('/Users/mrenke/Desktop/bars.pdf',bbox_inches='tight', tranparent=True)

# %%
# Out:
# /var/folders/3k/8g0xv78x051fznwyh_m5xcn8f91w3q/T/ipykernel_47169/3176964023.py:7: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "tranparent" which is no longer supported as of 3.3 and will become an error in 3.6
#   plt.savefig('/Users/mrenke/Desktop/bars.pdf',bbox_inches='tight', tranparent=True)

# %%
fig.get_facecolor()
# Out:
# (0.0, 0.0, 0.0, 0.0)
