# %%
import os
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import os.path as op
from stress_risk.utils.data import add_cond2df
import pandas as pd
#import pingouin
import statsmodels.api as sm

from utils import get_stress_level
df_stress_auc = get_stress_level()
df_stress_sr = pd.read_csv('/Users/mrenke/data/ds-stressrisk/addMeasures/selfRated_Stress.csv').set_index('subject') #self rated

# %%
df_n1_ev_sd = pd.read_csv('/Users/mrenke/data/ds-stressrisk/interim_sum_data/subwise_seswise_n1_evidence_sd.csv').set_index(['subject','session']) #subseswise
df_ch_risky_prior = pd.read_csv('/Users/mrenke/data/ds-stressrisk/interim_sum_data/subwise_change_risky_prior_model-1.csv').set_index('subject') # subwise

# %%
len(df_stress_auc)
# Out:
# 49

# %%
df_comb = df_stress_auc.join(df_ch_risky_prior, how='inner')

# %%
x = df_comb['AUC']
y = df_comb['risky_prior_mu']

x_quad = sm.add_constant(np.column_stack((x, x**2)))
model = sm.OLS(y, x_quad).fit()
print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         risky_prior_mu   R-squared:                       0.288
# Model:                            OLS   Adj. R-squared:                  0.257
# Method:                 Least Squares   F-statistic:                     9.288
# Date:                Tue, 09 Jul 2024   Prob (F-statistic):           0.000409
# Time:                        11:06:16   Log-Likelihood:                 2.7791
# No. Observations:                  49   AIC:                            0.4417
# Df Residuals:                      46   BIC:                             6.117
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0258      0.040      0.649      0.519      -0.054       0.106
# x1             0.0425      0.013      3.222      0.002       0.016       0.069
# x2            -0.0010      0.002     -0.555      0.581      -0.004       0.003
# ==============================================================================
# Omnibus:                        2.291   Durbin-Watson:                   2.028
# Prob(Omnibus):                  0.318   Jarque-Bera (JB):                1.467
# Skew:                           0.153   Prob(JB):                        0.480
# Kurtosis:                       2.209   Cond. No.                         41.4
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
